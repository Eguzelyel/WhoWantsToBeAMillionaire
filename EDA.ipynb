# %%
import json

with open('../train-v2.0.json') as json_file:
    data = json.load(json_file)
#     for p in data['people']:
#         print('Name: ' + p['name'])
#         print('Website: ' + p['website'])
#         print('From: ' + p['from'])
#         print('')

# %% [markdown]
# ## DO NOT TRY TO LOAD THE ENTIRE `data['data']`
# Don't even think about it.

# %%
print(len(data['data']))
data['data'][5]
# Out:
# 442
# {'paragraphs': [{'context': "Spectre (2015) is the twenty-fourth James Bond film produced by Eon Productions. It features Daniel Craig in his fourth performance as James Bond, and Christoph Waltz as Ernst Stavro Blofeld, with the film marking the character's re-introduction into the series. It was directed by Sam Mendes as his second James Bond film following Skyfall, and was written by John Logan, Neal Purvis, Robert Wade and Jez Butterworth. It is distributed by Metro-Goldwyn-Mayer and Columbia Pictures. With a budget around $245 million, it is the most expensive Bond film and one of the most expensive films ever made.",
#    'qas': [{'answers': [{'answer_start': 64, 'text': 'Eon Productions'}],
#      'id': '56cdaf0362d2951400fa6808',
#      'is_impossible': False,
#      'question': 'Which company made Spectre?'},
#     {'answers': [{'answer_start': 93, 'text': 'Daniel Craig'}],
#      'id': '56cdaf0362d2951400fa6809',
#      'is_impossible': False,
# ...
